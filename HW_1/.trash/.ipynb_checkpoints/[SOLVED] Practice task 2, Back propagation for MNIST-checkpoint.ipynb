# %% [markdown]
# ## Семинар 2 "Распознавание рукописных цифр"

# %% [markdown]
# ФИО: Петряйкин Федор Алексеевич

# %% [markdown]
# В этом задании мы используем нейронную сеть из предыдущего семинара для распознавания рукописных цифр. Также мы исследуем как влияет выбор нелинейности и предобработка данных на качество классификации.
#
# Чтобы не тратить время на подготовку данных, мы прилагаем готовый код с примером использования для получения обучающей и тестовой выборок. Для запуска скрипта вам понадобится библиотека PyTorch (инструкции по установке можно найти на сайте <a href="http://pytorch.org">pytorch.org</a>)

# %%
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, ConcatDataset
from torchvision.datasets import MNIST
from torchvision import transforms
import numpy as np
from scipy.stats import multivariate_normal
import sys
import layers
from layers import NeuralNetwork
# %matplotlib inline

# %%
import imp
import layers

# %%
np.random.seed(7)

# %%
imp.reload(layers)
# Out:
# <module 'layers' from 'F:\\TechnoSphere\\02_Neuro\\Lec2+hw2\\layers.py'>

# %%
transform = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])
train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
X, y = next(iter(train_loader))
X = X.numpy()
y = y.numpy()

# %%
plt.figure(figsize=(6, 7))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(X[i].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title(y[i])
    plt.axis('off')

# %% [markdown]
# ### Часть 1: MNIST
# Обучите полносвязную нейронную сеть с архитектурой 784-100-100-10 и сигмоидой в качестве нелинейности. Какую точность классификации удалось получить? Нарисуйте график сходимости на обучающей и тестовой выборках. В качестве темпа обучения (learning rate) возьмите 0.01

# %%
def blur_X(X, blur, rad, central):
    b_coeff = blur*np.random.random()
    weights = multivariate_normal([0, 0], [[b_coeff, 0], [0, b_coeff]])
    distr = np.zeros((rad*2, rad*2))
    for i in range(-rad, rad):
        for j in range(-rad, rad):
            distr[i+rad, j+rad] = weights.pdf([i, j])
                            
    for i in range(int(X.shape[0]/2.0)-central, int(X.shape[0]/2.0)+central):
        for j in range(int(X.shape[1]/2.0)-central, int(X.shape[1]/2.0)+central):
            X[i, j] = np.mean(X[i-rad:i+rad, j-rad:j+rad]*distr)

# %%
def train(network, epochs, learning_rate, verbose=False, train=train_loader, test=test_loader,
          blur=None, rad=2, central=10, blur_test=False):
    network.clear()
    train_loss_epochs = []
    test_loss_epochs = []
    train_accuracy_epochs = []
    test_accuracy_epochs = []
    
    try:
        for epoch in range(epochs):
            losses = []
            accuracies = []
            
            verbose_current = True #One grads for epoch
            for X, y in train:
                X = X.view(X.shape[0], -1).numpy()
                y = y.numpy()
                
                #blur
                if not blur is None:
                    blur_X(X, blur, rad, central)
                
                prediction = network.forward(X, verbose and verbose_current)
                loss_batch = network.getloss(y)
                losses.append(loss_batch)
                
                #пустая строка между forward и backward в выдаче
                if verbose and verbose_current:
                    print("")
                
                network.backward(y, verbose and verbose_current)
                verbose_current = False
                network.step(learning_rate)
                accuracies.append((np.argmax(prediction, 1) == y).mean())
            train_loss_epochs.append(np.mean(losses))
            train_accuracy_epochs.append(np.mean(accuracies))
            
            losses = []
            accuracies = []    
            for X, y in test:
                X = X.view(X.shape[0], -1).numpy()
                y = y.numpy()
                
                #blur
                if blur_test and (not blur is None):
                    blur_X(X, blur, rad, central)
                
                prediction = network.forward(X)
                loss_batch = network.getloss(y)
                losses.append(loss_batch)
                accuracies.append((np.argmax(prediction, 1) == y).mean())
            test_loss_epochs.append(np.mean(losses))
            test_accuracy_epochs.append(np.mean(accuracies))
            
            sys.stdout.write('\nEpoch {0}... (Train/Test) NLL: {1:.3f}/{2:.3f}\tAccuracy: {3:.3f}/{4:.3f}\n'.format(
                        epoch, train_loss_epochs[-1], test_loss_epochs[-1],
                        train_accuracy_epochs[-1], test_accuracy_epochs[-1]))
    except KeyboardInterrupt:
        pass
    finally:
        sys.stdout.write('\nBest for test: {0}'.format(max(test_accuracy_epochs)))
    
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_loss_epochs, label='Train')
    plt.plot(test_loss_epochs, label='Test')
    plt.xlabel('Epochs', fontsize=16)
    plt.ylabel('Loss', fontsize=16)
    plt.legend(loc=0, fontsize=16)
    plt.grid('on')
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracy_epochs, label='Train accuracy')
    plt.plot(test_accuracy_epochs, label='Test accuracy')
    plt.xlabel('Epochs', fontsize=16)
    plt.ylabel('Loss', fontsize=16)
    plt.legend(loc=0, fontsize=16)
    plt.grid('on')
    plt.show()

# %%
imp.reload(layers)
# Out:
# <module 'layers' from 'F:\\TechnoSphere\\02_Neuro\\Lec2+hw2\\layers.py'>

# %% [markdown]
# #### Обучение с различными нелинейностями

# %% [markdown]
# *3 линейных слоя, сигмоиды, SoftMax*

# %% [markdown]
# Для понимания динамики обучения, будем печатать dLdy и коэффициенты в каждой эпохе

# %%
network_sigmioid = NeuralNetwork([layers.Linear(784, 100), layers.Sigmoid(), layers.Linear(100, 100), 
                                  layers.Sigmoid(), layers.Linear(100, 10), layers.SoftMax_NLLLoss()])

# %%
train(network_sigmioid, 20, 0.1, True)
# Out:
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.94e-03; W_std = 9.94e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.90e-03; W_std = 9.90e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 3 <class 'layers.Sigmoid'> , coeff: No coeff
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.91e-03; W_std = 1.00e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.63e-03 ; std: 9.38e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.31e-04 ; std: 2.91e-04
# 3 <class 'layers.Sigmoid'> , mean (abs) grad: 5.78e-05 ; std: 7.27e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 5.45e-06 ; std: 6.89e-06
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 1.34e-06 ; std: 1.69e-06
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.31e-07 ; std: 1.65e-07
#
# Epoch 0... (Train/Test) NLL: 1.855/0.746	Accuracy: 0.310/0.803
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.46e-02; W_std = 2.02e-02 | b_mean (abs) = 5.45e-03; b_std = 6.52e-03
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.05e-02; W_std = 6.28e-02 | b_mean (abs) = 1.73e-02; b_std = 2.09e-02
# 3 <class 'layers.Sigmoid'> , coeff: No coeff
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.84e-01; W_std = 2.31e-01 | b_mean (abs) = 9.78e-02; b_std = 1.34e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.29e-03 ; std: 4.83e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.44e-03 ; std: 2.01e-03
# 3 <class 'layers.Sigmoid'> , mean (abs) grad: 2.87e-04 ; std: 4.28e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.02e-03 ; std: 1.45e-03
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 1.20e-04 ; std: 2.24e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 9.39e-05 ; std: 1.92e-04
#
# Epoch 1... (Train/Test) NLL: 0.479/0.336	Accuracy: 0.872/0.910
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.15e-02; W_std = 3.10e-02 | b_mean (abs) = 1.48e-02; b_std = 1.82e-02
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.27e-02; W_std = 9.21e-02 | b_mean (abs) = 2.65e-02; b_std = 3.35e-02
# 3 <class 'layers.Sigmoid'> , coeff: No coeff
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.86e-01; W_std = 3.41e-01 | b_mean (abs) = 1.00e-01; b_std = 1.41e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.41e-03 ; std: 4.41e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.88e-03 ; std: 3.81e-03
# 3 <class 'layers.Sigmoid'> , mean (abs) grad:
0.975
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.53e-02; W_std = 6.66e-02 | b_mean (abs) = 3.82e-02; b_std = 4.53e-02
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.45e-01; W_std = 1.84e-01 | b_mean (abs) = 5.17e-02; b_std = 6.35e-02
# 3 <class 'layers.Sigmoid'> , coeff: No coeff
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.47e-01; W_std = 6.42e-01 | b_mean (abs) = 1.23e-01; b_std = 1.77e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 4.77e-05 ; std: 2.36e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.41e-04 ; std: 4.43e-04
# 3 <class 'layers.Sigmoid'> , mean (abs) grad: 3.03e-05 ; std: 9.86e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.42e-04 ; std: 7.30e-04
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 1.22e-05 ; std: 6.47e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.76e-05 ; std: 5.56e-05
#
# Epoch 19... (Train/Test) NLL: 0.015/0.093	Accuracy: 0.998/0.974
#
# Best for test: 0.9747404153354633

# %% [markdown]
# * Нормально обучающаяся нейронная сеть. Нет больших коэффициентов в начальных слоях (отрыва от данных). Коэффициенты в первых слоях мало изменяются - некоторое затухание, сигмоида остается вблизи 0.

# %% [markdown]
# Обучите нейронную сеть с другими нелинейностями: ReLU и ELU. Сравните скорости сходимости и качество классификации с различными функциями активации.

# %%
elu_layer = layers.ELU()
x = np.arange(-10, 10, 0.1)
y = elu_layer.forward(x)
print("ELU")
plt.plot(x, y)
# Out:
# ELU

# %%
relu_layer = layers.ReLU()
y = relu_layer.forward(x)
print("ReLU")
plt.plot(x, y)
# Out:
# ReLU

# %% [markdown]
# *3 линейных слоя, ELU (с изменяющимся параметром), SoftMax*

# %%
network_elu_notfixed = NeuralNetwork([layers.Linear(784, 100), layers.ELU(), layers.Linear(100, 100), 
                                      layers.ELU(), layers.Linear(100, 10), layers.SoftMax_NLLLoss()])

# %%
train(network_elu_notfixed, 20, 0.05, True) #С 0.1 учить нельзя - градиент elu очень быстро начинает "скакать" вокруг минимума
# Out:
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.98e-03; W_std = 1.00e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 1 <class 'layers.ELU'> , coeff: 1.00e+00
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.94e-03; W_std = 9.97e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 3 <class 'layers.ELU'> , coeff: 1.00e+00
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.25e-03; W_std = 1.03e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.63e-03 ; std: 9.38e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.42e-04 ; std: 3.04e-04
# 3 <class 'layers.ELU'> , mean (abs) grad: 2.42e-04 ; std: 3.04e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.38e-05 ; std: 2.99e-05
# 1 <class 'layers.ELU'> , mean (abs) grad: 2.38e-05 ; std: 2.99e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.40e-06 ; std: 3.02e-06
#
# Epoch 0... (Train/Test) NLL: 0.557/0.278	Accuracy: 0.827/0.915
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.53e-02; W_std = 2.10e-02 | b_mean (abs) = 8.41e-03; b_std = 9.61e-03
# 1 <class 'layers.ELU'> , coeff: 9.13e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.70e-02; W_std = 3.53e-02 | b_mean (abs) = 1.11e-02; b_std = 1.34e-02
# 3 <class 'layers.ELU'> , coeff: 9.25e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.37e-02; W_std = 1.06e-01 | b_mean (abs) = 8.86e-02; b_std = 1.28e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 8.25e-04 ; std: 3.75e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 4.52e-04 ; std: 1.28e-03
# 3 <class 'layers.ELU'> , mean (abs) grad: 4.37e-04 ; std: 1.24e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.88e-04 ; std: 1.38e-03
# 1 <class 'layers.ELU'> , mean (abs) grad: 4.64e-04 ; std: 1.32e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.50e-04 ; std: 7.98e-04
#
# Epoch 1... (Train/Test) NLL: 0.253/0.224	Accuracy: 0.925/0.930
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.84e-02; W_std = 2.54e-02 | b_mean (abs) = 1.18e-02; b_std = 1.33e-02
# 1 <class 'layers.ELU'> , coeff: 7.93e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.08e-02; W_std = 4.05e-02 | b_mean (abs) = 1.45e-02; b_std = 1.76e-02
# 3 <class 'layers.ELU'> , coeff: 8.24e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 9.61e-02; W_std = 1.23e-01 | b_mean (abs) = 9.78e-02; b_std = 1.40e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 8.34e-04 ; std: 3.44e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 5.27e-04 ; std: 1.45e-03
# 3 <class 'layers.ELU'> , mean (abs) grad: 4.86e-04 ; std: 1.37e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 6.68e-04 ; std: 1.86e-03
# 1 <class 'layers.ELU'> , mean (abs) grad: 5.75e-04 ; std: 1.61e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 3.98e-04 ; std: 1.22e-03
#
# Epoch 2... (Train/Test) NLL: 0.198/0.176	Accuracy: 0.940/0.944
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.07e-02; W_std = 2.89e-02 | b_mean (abs) = 1.42e-02; b_std = 1.53e-02
# 1 <class 'layers.ELU'> , coeff: 6.65e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.51e-02; W_std = 4.61e-02 | b_mean (abs) = 1.56e-02; b_std = 1.91e-02
# 3 <class 'layers.ELU'> , coeff: 7.19e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.07e-01; W_std = 1.38e-01 | b_mean (abs) = 1.01e-01; b_std = 1.41e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.57e-04 ; std: 7.17e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.10e-04 ; std: 3.24e-04
# 3 <class 'layers.ELU'> , mean (abs) grad: 9.41e-05 ; std: 2.83e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.48e-04 ; std: 4.24e-04
# 1 <class 'layers.ELU'> , mean (abs) grad: 1.12e-04 ; std: 3.17e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 8.01e-05 ; std: 2.59e-04
#
# Epoch 3... (Train/Test) NLL: 0.149/0.150	Accuracy: 0.954/0.956
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.25e-02; W_std = 3.14e-02 | b_mean (abs) = 1.59e-02; b_std = 1.60e-02
# 1 <class 'layers.ELU'> , coeff: 5.38e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.87e-02; W_std = 5.08e-02 | b_mean (abs) = 1.56e-02; b_std = 1.93e-02
# 3 <class 'layers.ELU'> , coeff: 6.20e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.16e-01; W_std = 1.50e-01 | b_mean (abs) = 1.01e-01; b_std = 1.39e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 6.42e-04 ; std: 3.22e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 4.62e-04 ; std: 1.52e-03
# 3 <class 'layers.ELU'> , mean (abs) grad: 3.87e-04 ; std: 1.34e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 6.87e-04 ; std: 2.20e-03
# 1 <class 'layers.ELU'> , mean (abs) grad: 4.54e-04 ; std: 1.53e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 3.63e-04 ; std: 1.27e-03
#
# Epoch 4... (Train/Test) NLL: 0.113/0.120	Accuracy: 0.965/0.963
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.43e-02; W_std = 3.41e-02 | b_mean (abs) = 1.76e-02; b_std = 1.75e-02
# 1 <class 'layers.ELU'> , coeff: 4.21e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.24e-02; W_std = 5.55e-02 | b_mean (abs) = 1.66e-02; b_std = 2.02e-02
# 3 <class 'layers.ELU'> , coeff: 5.33e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.26e-01; W_std = 1.62e-01 | b_mean (abs) = 1.00e-01; b_std = 1.37e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.65e-04 ; std: 1.87e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.99e-04 ; std: 9.96e-04
# 3 <class 'layers.ELU'> , mean (abs) grad: 2.42e-04 ; std: 8.66e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.59e-04 ; std: 1.58e-03
# 1 <class 'layers.ELU'> , mean (abs) grad: 2.57e-04 ; std: 9.61e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.21e-04 ; std: 7.83e-04
#
# Epoch 5... (Train/Test) NLL: 0.088/0.109	Accuracy: 0.973/0.966
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.59e-02; W_std = 3.65e-02 | b_mean (abs) = 1.89e-02; b_std = 1.76e-02
# 1 <class 'layers.ELU'> , coeff: 3.11e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.54e-02; W_std = 5.94e-02 | b_mean (abs) = 1.79e-02; b_std = 2.10e-02
# 3 <class 'layers.ELU'> , coeff: 4.57e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.33e-01; W_std = 1.71e-01 | b_mean (abs) = 9.91e-02; b_std = 1.34e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.10e-04 ; std: 2.16e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.77e-04 ; std: 1.15e-03
# 3 <class 'layers.ELU'> , mean (abs) grad: 2.17e-04 ; std: 9.77e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.34e-04 ; std: 1.81e-03
# 1 <class 'layers.ELU'> , mean (abs) grad: 1.92e-04 ; std: 9.07e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 1
-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.56e-01; W_std = 2.01e-01 | b_mean (abs) = 1.11e-01; b_std = 1.44e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.56e-04 ; std: 1.74e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.57e-04 ; std: 1.07e-03
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.18e-04 ; std: 9.44e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 3.19e-04 ; std: 2.04e-03
# 1 <class 'layers.ELU'> , mean (abs) grad: 1.19e-04 ; std: 1.20e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 8.99e-05 ; std: 6.65e-04
#
# Epoch 11... (Train/Test) NLL: 0.026/0.091	Accuracy: 0.992/0.976
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.14e-02; W_std = 4.52e-02 | b_mean (abs) = 2.22e-02; b_std = 2.09e-02
# 1 <class 'layers.ELU'> , coeff: -1.50e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.64e-02; W_std = 7.34e-02 | b_mean (abs) = 4.55e-02; b_std = 5.83e-02
# 3 <class 'layers.ELU'> , coeff: 1.99e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.58e-01; W_std = 2.05e-01 | b_mean (abs) = 1.12e-01; b_std = 1.48e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.30e-05 ; std: 1.72e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.73e-05 ; std: 1.23e-04
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.94e-05 ; std: 1.06e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 5.35e-05 ; std: 2.47e-04
# 1 <class 'layers.ELU'> , mean (abs) grad: 2.19e-05 ; std: 1.40e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.47e-05 ; std: 8.41e-05
#
# Epoch 12... (Train/Test) NLL: 0.021/0.099	Accuracy: 0.993/0.976
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.19e-02; W_std = 4.60e-02 | b_mean (abs) = 2.20e-02; b_std = 2.07e-02
# 1 <class 'layers.ELU'> , coeff: -2.01e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.76e-02; W_std = 7.50e-02 | b_mean (abs) = 4.94e-02; b_std = 6.35e-02
# 3 <class 'layers.ELU'> , coeff: 1.78e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.61e-01; W_std = 2.08e-01 | b_mean (abs) = 1.17e-01; b_std = 1.54e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.99e-05 ; std: 1.21e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.19e-05 ; std: 7.56e-05
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.56e-05 ; std: 6.60e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.07e-05 ; std: 1.43e-04
# 1 <class 'layers.ELU'> , mean (abs) grad: 1.78e-05 ; std: 7.42e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.14e-05 ; std: 4.01e-05
#
# Epoch 13... (Train/Test) NLL: 0.017/0.103	Accuracy: 0.995/0.975
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.23e-02; W_std = 4.67e-02 | b_mean (abs) = 2.16e-02; b_std = 2.04e-02
# 1 <class 'layers.ELU'> , coeff: -2.45e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.87e-02; W_std = 7.63e-02 | b_mean (abs) = 5.26e-02; b_std = 6.77e-02
# 3 <class 'layers.ELU'> , coeff: 1.62e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.63e-01; W_std = 2.11e-01 | b_mean (abs) = 1.19e-01; b_std = 1.58e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.06e-04 ; std: 2.00e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.24e-04 ; std: 1.39e-03
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.59e-04 ; std: 1.25e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.83e-04 ; std: 2.83e-03
# 1 <class 'layers.ELU'> , mean (abs) grad: 2.53e-04 ; std: 1.89e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.64e-04 ; std: 1.13e-03
#
# Epoch 14... (Train/Test) NLL: 0.013/0.098	Accuracy: 0.996/0.977
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.28e-02; W_std = 4.74e-02 | b_mean (abs) = 2.14e-02; b_std = 2.05e-02
# 1 <class 'layers.ELU'> , coeff: -2.83e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.97e-02; W_std = 7.76e-02 | b_mean (abs) = 5.47e-02; b_std = 7.05e-02
# 3 <class 'layers.ELU'> , coeff: 1.50e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.66e-01; W_std = 2.14e-01 | b_mean (abs) = 1.20e-01; b_std = 1.60e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.64e-05 ; std: 1.79e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.85e-05 ; std: 1.23e-04
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.27e-05 ; std: 1.01e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 3.49e-05 ; std: 2.29e-04
# 1 <class 'layers.ELU'> , mean (abs) grad: 1.76e-05 ; std: 1.36e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 9.87e-06 ; std: 7.30e-05
#
# Epoch 15... (Train/Test) NLL: 0.011/0.111	Accuracy: 0.996/0.975
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.32e-02; W_std = 4.81e-02 | b_mean (abs) = 2.12e-02; b_std = 2.04e-02
# 1 <class 'layers.ELU'> , coeff: -3.16e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 6.06e-02; W_std = 7.88e-02 | b_mean (abs) = 5.69e-02; b_std = 7.33e-02
# 3 <class 'layers.ELU'> , coeff: 1.39e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.68e-01; W_std = 2.17e-01 | b_mean (abs) = 1.22e-01; b_std = 1.63e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.98e-05 ; std: 7.31e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 7.55e-05 ; std: 5.40e-04
# 3 <class 'layers.ELU'> , mean (abs) grad: 5.23e-05 ; std: 4.41e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.49e-04 ; std: 1.03e-03
# 1 <class 'layers.ELU'> , mean (abs) grad: 8.19e-05 ; std: 6.63e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 4.39e-05 ; std: 3.72e-04
#
# Epoch 16... (Train/Test) NLL: 0.008/0.103	Accuracy: 0.998/0.977
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.35e-02; W_std = 4.86e-02 | b_mean (abs) = 2.12e-02; b_std = 2.07e-02
# 1 <class 'layers.ELU'> , coeff: -3.41e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 6.15e-02; W_std = 7.98e-02 | b_mean (abs) = 5.77e-02; b_std = 7.45e-02
# 3 <class 'layers.ELU'> , coeff: 1.33e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.70e-01; W_std = 2.20e-01 | b_mean (abs) = 1.22e-01; b_std = 1.64e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.18e-05 ; std: 1.34e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.40e-05 ; std: 9.77e-05
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.60e-05 ; std: 7.86e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.48e-05 ; std: 1.84e-04
# 1 <class 'layers.ELU'> , mean (abs) grad: 2.65e-05 ; std: 1.24e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.40e-05 ; std: 6.48e-05
# Epoch 17... (Train/Test) NLL: 0.010/0.112	Accuracy: 0.997/0.976
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.39e-02; W_std = 4.92e-02 | b_mean (abs) = 2.11e-02; b_std = 2.03e-02
# 1 <class 'layers.ELU'> , coeff: -3.74e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 6.22e-02; W_std = 8.07e-02 | b_mean (abs) = 5.95e-02; b_std = 7.68e-02
# 3 <class 'layers.ELU'> , coeff: 1.24e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.71e-01; W_std = 2.22e-01 | b_mean (abs) = 1.24e-01; b_std = 1.66e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.23e-06 ; std: 1.88e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.62e-06 ; std: 1.32e-05
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.97e-06 ; std: 1.19e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 6.24e-06 ; std: 3.04e-05
# 1 <class 'layers.ELU'> , mean (abs) grad: 3.62e-06 ; std: 2.06e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.01e-06 ; std: 1.22e-05
#
# Epoch 18... (Train/Test) NLL: 0.007/0.111	Accuracy: 0.998/0.976
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.41e-02; W_std = 4.97e-02 | b_mean (abs) = 2.07e-02; b_std = 2.01e-02
# 1 <class 'layers.ELU'> , coeff: -3.95e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 6.29e-02; W_std = 8.16e-02 | b_mean (abs) = 6.02e-02; b_std = 7.81e-02
# 3 <class 'layers.ELU'> , coeff: 1.19e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.73e-01; W_std = 2.24e-01 | b_mean (abs) = 1.25e-01; b_std = 1.68e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 4.41e-05 ; std: 3.49e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 5.29e-05 ; std: 2.41e-04
# 3 <class 'layers.ELU'> , mean (abs) grad: 3.71e-05 ; std: 2.15e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.22e-04 ; std: 5.57e-04
# 1 <class 'layers.ELU'> , mean (abs) grad: 6.74e-05 ; std: 3.25e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 3.40e-05 ; std: 1.90e-04
#
# Epoch 19... (Train/Test) NLL: 0.003/0.111	Accuracy: 0.999/0.977
#
# Best for test: 0.9768370607028753

# %% [markdown]
# * Аналогично сети на сигмоидах, чуть лучше качество, но немного медленнее обучается

# %% [markdown]
# *3 линейных слоя, ELU (с фиксированным параметром), SoftMax*

# %%
network_elu_fixed = NeuralNetwork([layers.Linear(784, 100), layers.ELU(alpha0=0.1, fixed=True), layers.Linear(100, 100), 
                                   layers.ELU(alpha0=0.1, fixed=True), layers.Linear(100, 10), layers.SoftMax_NLLLoss()])

# %%
train(network_elu_fixed, 20, 0.05, True)
# Out:
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7
0.979
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.68e-02; W_std = 4.08e-02 | b_mean (abs) = 1.20e-02; b_std = 1.45e-02
# 1 <class 'layers.ELU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.52e-02; W_std = 7.57e-02 | b_mean (abs) = 3.13e-02; b_std = 3.41e-02
# 3 <class 'layers.ELU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.65e-01; W_std = 2.18e-01 | b_mean (abs) = 6.50e-02; b_std = 7.64e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 6.65e-07 ; std: 3.68e-06
# 4 <class 'layers.Linear'> , mean (abs) grad: 7.21e-07 ; std: 2.73e-06
# 3 <class 'layers.ELU'> , mean (abs) grad: 5.76e-07 ; std: 2.46e-06
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.68e-06 ; std: 6.29e-06
# 1 <class 'layers.ELU'> , mean (abs) grad: 6.94e-07 ; std: 3.39e-06
# 0 <class 'layers.Linear'> , mean (abs) grad: 4.35e-07 ; std: 1.78e-06
#
# Epoch 16... (Train/Test) NLL: 0.002/0.089	Accuracy: 1.000/0.981
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.69e-02; W_std = 4.10e-02 | b_mean (abs) = 1.23e-02; b_std = 1.47e-02
# 1 <class 'layers.ELU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.57e-02; W_std = 7.64e-02 | b_mean (abs) = 3.16e-02; b_std = 3.44e-02
# 3 <class 'layers.ELU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.67e-01; W_std = 2.21e-01 | b_mean (abs) = 6.50e-02; b_std = 7.65e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.09e-06 ; std: 1.91e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.43e-06 ; std: 1.32e-05
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.78e-06 ; std: 1.10e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.75e-06 ; std: 2.44e-05
# 1 <class 'layers.ELU'> , mean (abs) grad: 2.03e-06 ; std: 1.34e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.50e-06 ; std: 8.30e-06
# Epoch 17... (Train/Test) NLL: 0.001/0.089	Accuracy: 1.000/0.980
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.70e-02; W_std = 4.11e-02 | b_mean (abs) = 1.21e-02; b_std = 1.46e-02
# 1 <class 'layers.ELU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.61e-02; W_std = 7.69e-02 | b_mean (abs) = 3.17e-02; b_std = 3.45e-02
# 3 <class 'layers.ELU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.68e-01; W_std = 2.22e-01 | b_mean (abs) = 6.51e-02; b_std = 7.67e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.99e-06 ; std: 3.76e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 6.88e-06 ; std: 2.67e-05
# 3 <class 'layers.ELU'> , mean (abs) grad: 5.11e-06 ; std: 2.26e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.55e-05 ; std: 5.49e-05
# 1 <class 'layers.ELU'> , mean (abs) grad: 7.30e-06 ; std: 3.66e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 4.92e-06 ; std: 2.20e-05
#
# Epoch 18... (Train/Test) NLL: 0.001/0.091	Accuracy: 1.000/0.980
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.71e-02; W_std = 4.12e-02 | b_mean (abs) = 1.22e-02; b_std = 1.47e-02
# 1 <class 'layers.ELU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.64e-02; W_std = 7.73e-02 | b_mean (abs) = 3.19e-02; b_std = 3.47e-02
# 3 <class 'layers.ELU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.70e-01; W_std = 2.24e-01 | b_mean (abs) = 6.53e-02; b_std = 7.69e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.69e-06 ; std: 1.63e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.89e-06 ; std: 1.20e-05
# 3 <class 'layers.ELU'> , mean (abs) grad: 2.39e-06 ; std: 1.11e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 7.49e-06 ; std: 2.83e-05
# 1 <class 'layers.ELU'> , mean (abs) grad: 2.85e-06 ; std: 1.46e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.05e-06 ; std: 8.57e-06
#
# Epoch 19... (Train/Test) NLL: 0.001/0.092	Accuracy: 1.000/0.980
#
# Best for test: 0.9805311501597445

# %% [markdown]
# * Быстро обучается, хорошее качество

# %% [markdown]
# *3 линейных слоя, ReLU (с фиксированным параметром), SoftMax*

# %%
#Коэффициент в ReLU лучше не обучать - очень плохо сходится
network_relu_fixed = NeuralNetwork([layers.Linear(784, 100), layers.ReLU(fixed=True), layers.Linear(100, 100), 
                                    layers.ReLU(fixed=True), layers.Linear(100, 10), layers.SoftMax_NLLLoss()])

# %%
train(network_relu_fixed, 20, 0.05, True)
# Out:
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.99e-03; W_std = 1.00e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.99e-03; W_std = 1.00e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.01e-03; W_std = 9.86e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5
-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.20e-06 ; std: 8.43e-06
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.37e-06 ; std: 5.79e-06
# 3 <class 'layers.ReLU'> , mean (abs) grad: 9.51e-07 ; std: 4.77e-06
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.62e-06 ; std: 1.06e-05
# 1 <class 'layers.ReLU'> , mean (abs) grad: 1.20e-06 ; std: 6.64e-06
# 0 <class 'layers.Linear'> , mean (abs) grad: 7.93e-07 ; std: 3.78e-06
#
# Epoch 16... (Train/Test) NLL: 0.005/0.090	Accuracy: 0.999/0.980
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.83e-02; W_std = 4.29e-02 | b_mean (abs) = 1.29e-02; b_std = 1.54e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.60e-02; W_std = 7.74e-02 | b_mean (abs) = 2.53e-02; b_std = 3.28e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.63e-01; W_std = 2.18e-01 | b_mean (abs) = 9.59e-02; b_std = 1.21e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.40e-05 ; std: 2.49e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.38e-05 ; std: 1.67e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.46e-05 ; std: 1.26e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.45e-05 ; std: 3.05e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 2.17e-05 ; std: 2.15e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.74e-05 ; std: 1.29e-04
# Epoch 17... (Train/Test) NLL: 0.004/0.091	Accuracy: 0.999/0.978
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.85e-02; W_std = 4.32e-02 | b_mean (abs) = 1.31e-02; b_std = 1.55e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.65e-02; W_std = 7.82e-02 | b_mean (abs) = 2.54e-02; b_std = 3.29e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.65e-01; W_std = 2.20e-01 | b_mean (abs) = 9.60e-02; b_std = 1.21e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 4.53e-06 ; std: 4.70e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 5.01e-06 ; std: 3.24e-05
# 3 <class 'layers.ReLU'> , mean (abs) grad: 3.83e-06 ; std: 2.95e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.31e-05 ; std: 7.63e-05
# 1 <class 'layers.ReLU'> , mean (abs) grad: 4.41e-06 ; std: 3.42e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.88e-06 ; std: 1.74e-05
#
# Epoch 18... (Train/Test) NLL: 0.002/0.090	Accuracy: 1.000/0.979
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.86e-02; W_std = 4.34e-02 | b_mean (abs) = 1.31e-02; b_std = 1.55e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.70e-02; W_std = 7.88e-02 | b_mean (abs) = 2.56e-02; b_std = 3.32e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.66e-01; W_std = 2.23e-01 | b_mean (abs) = 9.61e-02; b_std = 1.21e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.43e-06 ; std: 2.14e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.61e-06 ; std: 1.42e-05
# 3 <class 'layers.ReLU'> , mean (abs) grad: 2.10e-06 ; std: 1.32e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 6.21e-06 ; std: 3.06e-05
# 1 <class 'layers.ReLU'> , mean (abs) grad: 2.70e-06 ; std: 1.86e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.82e-06 ; std: 1.08e-05
#
# Epoch 19... (Train/Test) NLL: 0.002/0.091	Accuracy: 1.000/0.979
#
# Best for test: 0.9803314696485623

# %% [markdown]
# ** Промежуточные выводы **
# Теоретически, ELU и ReLU лучше сигмоиды: они позволяют уменьшить затухание градиентов и увеличить зависимость последнего слоя от входных данных (избежать возрастания его коэффициентов), но на малых сетях это практически не заметно. ReLU и ELU с фиксированными параметрами дают лучшее качество как нелинейности для данных сетей

# %% [markdown]
# ### Часть 2: Анализ ошибок

# %%
def ShowIncorrect(network):
    wrong_X = []
    correct_y = []
    predicted_y = []
    logits = []
    for X, y in test_loader:
        X = X.view(X.shape[0], -1).numpy()
        y = y.numpy()

        prediction = network.forward(X)
        prediction = np.exp(prediction)
        prediction /= prediction.sum(1, keepdims=True)
        for i in range(len(prediction)):
            if np.argmax(prediction[i]) != y[i]:
                wrong_X.append(X[i])
                correct_y.append(y[i])
                predicted_y.append(np.argmax(prediction[i]))
                logits.append(prediction[i][y[i]])

    wrong_X = np.row_stack(wrong_X)
    correct_y = np.row_stack(correct_y)[:, 0]
    predicted_y = np.row_stack(predicted_y)[:, 0]
    logits = np.row_stack(logits)[:, 0]
    
    plt.figure(figsize=(10, 5))
    order = np.argsort(logits)
    for i in range(21):
        plt.subplot(3, 7, i+1)
        plt.imshow(wrong_X[order[i]].reshape(28, 28), cmap=plt.cm.Greys_r)
        plt.title('{}({})'.format(correct_y[order[i]], predicted_y[order[i]]), fontsize=20)
        plt.axis('off')

# %%
ShowIncorrect(network_sigmioid)

# %% [markdown]
# #### Влияние различных архитектур сетей

# %% [markdown]
# *Увеличение количества слоев*

# %%
# Попробуем увеличить число слоев + 2 типа нелинейностей
network_mixed = NeuralNetwork([layers.Linear(784, 100), layers.ReLU(fixed=True),
                               layers.Linear(100, 300), layers.ELU(fixed=True, alpha0=0.1), 
                               layers.Linear(300, 200), layers.ReLU(fixed=True), layers.Linear(200, 10),
                               layers.SoftMax_NLLLoss()])
train(network_mixed, 20, 0.1, True)
# Out:
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.95e-03; W_std = 9.97e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.92e-03; W_std = 9.92e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 3 <class 'layers.ELU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.00e-03; W_std = 1.00e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 5 <class 'layers.ReLU'> , coeff: 1.00e-01
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.96e-03; W_std = 1.00e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 7 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 7 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.63e-03 ; std: 9.38e-03
# 6 <class 'layers.Linear'> , mean (abs) grad: 2.37e-04 ; std: 2.96e-04
# 5 <class 'layers.ReLU'> , mean (abs) grad: 1.31e-04 ; std: 2.10e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.41e-05 ; std: 3.01e-05
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.37e-05 ; std: 2.19e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.95e-06 ; std: 3.72e-06
# 1 <class 'layers.ReLU'> , mean (abs) grad: 1.70e-06 ; std: 2.72e-06
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.15e-07 ; std: 2.73e-07
#
# Epoch 0... (Train/Test) NLL: 0.855/0.183	Accuracy: 0.694/0.945
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.72e-02; W_std = 2.56e-02 | b_mean (abs) = 7.18e-03; b_std = 8.11e-03
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.74e-02; W_std = 2.41e-02 | b_mean (abs) = 9.68e-03; b_std = 9.40e-03
# 3 <class 'layers.ELU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.29e-02; W_std = 1.75e-02 | b_mean (abs) = 2.00e-02; b_std = 2.58e-02
# 5 <class 'layers.ReLU'> , coeff: 1.00e-01
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 6.70e-02; W_std = 9.28e-02 | b_mean (abs) = 1.92e-01; b_std = 2.26e-01
# 7 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 7 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 6.26e-04 ; std: 2.94e-03
# 6 <class 'layers.Linear'> , mean (abs) grad: 2.63e-04 ; std: 9.47e-04
# 5 <class 'layers.ReLU'> , mean (abs) grad: 1.93e-04 ; std: 8.43e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.47e-04 ; std: 8.86e-04
# 3 <class 'layers.ELU'> , mean (abs) grad: 1.66e-04 ; std: 7.43e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 5.07e-04 ; std: 1.71e-03
# 1 <class 'layers.ReLU'> , mean (abs) grad: 2.09e-04 ; std: 1.03e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.36e-04 ; std: 5.19e-04
#
# Epoch 1... (Train/Test) NLL: 0.149/0.116	Accuracy: 0.955/0.964
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.15e-02; W_std = 3.29e-02 | b_mean (abs) = 1.17e-02; b_std = 1.12e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.16e-02; W_std = 2.99e-02 | b_mean (abs) = 1.31e-02; b_std = 1.60e-02
# 3 <class 'layers.ELU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.41e-02; W_std = 1.92e-02 | b_mean (abs) = 2.35e-02; b_std = 2.98e-02
# 5 <class 'layers.ReLU'> , coeff: 1.00e-01
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.31e-02; W_std = 1.01e-01 | b_mean (abs) = 1.87e-01; b_std = 2.12e-01
# 7 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 7 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.04e-04 ; std: 2.25e-03
# 6 <class 'layers.Linear'> , mean (abs) grad: 1.38e-04 ; std: 6.62e-04
# 5 <class 'layers.ReLU'> , mean (abs) grad: 8.09e-05 ; std: 5.25e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.10e-04 ; std: 5.27e-04
# 3 <class 'layers.ELU'> , mean (abs) grad: 6.10e-05 ; std: 3.82e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.21e-04 ; std: 9.60e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 8.87e-05 ; std: 5.60e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 6.17e-05 ; std: 2.81e-04
#
# Epoch 2... (Train/Test) NLL: 0.100/0.095	Accuracy: 0.970/0.971
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.45e-02; W_std = 3.76e-02 | b_mean (abs) = 1.47e-02; b_std = 1.38e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.44e-02; W_std = 3.37e-02 | b_mean (abs) = 1.51e-02; b_std = 1.99e-02
# 3 <class 'layers.ELU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.47e-02; W_std = 2.03e-02 | b_mean (abs) = 2.57e-02; b_std = 3.27e-02
# 5 <class 'layers.ReLU'> , coeff: 1.00e-01
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 7
-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.46e-02; W_std = 6.06e-02 | b_mean (abs) = 2.71e-02; b_std = 3.60e-02
# 3 <class 'layers.ELU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.09e-02; W_std = 2.96e-02 | b_mean (abs) = 3.57e-02; b_std = 4.87e-02
# 5 <class 'layers.ReLU'> , coeff: 1.00e-01
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 9.59e-02; W_std = 1.30e-01 | b_mean (abs) = 2.02e-01; b_std = 2.20e-01
# 7 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 7 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 6.21e-08 ; std: 4.87e-07
# 6 <class 'layers.Linear'> , mean (abs) grad: 3.99e-08 ; std: 2.05e-07
# 5 <class 'layers.ReLU'> , mean (abs) grad: 2.12e-08 ; std: 1.42e-07
# 4 <class 'layers.Linear'> , mean (abs) grad: 4.84e-08 ; std: 2.41e-07
# 3 <class 'layers.ELU'> , mean (abs) grad: 2.24e-08 ; std: 1.62e-07
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.31e-07 ; std: 6.34e-07
# 1 <class 'layers.ReLU'> , mean (abs) grad: 4.30e-08 ; std: 3.34e-07
# 0 <class 'layers.Linear'> , mean (abs) grad: 5.00e-08 ; std: 3.09e-07
#
# Epoch 19... (Train/Test) NLL: 0.017/0.097	Accuracy: 0.995/0.981
#
# Best for test: 0.9807308306709265

# %% [markdown]
# * Простое увеличние количества слоев значительно не увеличивает качество. Вероятно, сеть переобучается

# %%
# Та же нейронная сеть на сигмоидах
network_mixed = NeuralNetwork([layers.Linear(784, 100), layers.Sigmoid(),
                               layers.Linear(100, 300), layers.Sigmoid(), 
                               layers.Linear(300, 200), layers.Sigmoid(), layers.Linear(200, 10),
                               layers.SoftMax_NLLLoss()])
train(network_mixed, 30, 0.1, True)
# Out:
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.95e-03; W_std = 9.98e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.98e-03; W_std = 1.00e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 3 <class 'layers.Sigmoid'> , coeff: No coeff
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.00e-03; W_std = 1.00e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 5 <class 'layers.Sigmoid'> , coeff: No coeff
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.03e-03; W_std = 1.01e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 7 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 7 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.63e-03 ; std: 9.38e-03
# 6 <class 'layers.Linear'> , mean (abs) grad: 2.37e-04 ; std: 2.99e-04
# 5 <class 'layers.Sigmoid'> , mean (abs) grad: 5.92e-05 ; std: 7.45e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 8.26e-06 ; std: 1.04e-05
# 3 <class 'layers.Sigmoid'> , mean (abs) grad: 2.06e-06 ; std: 2.60e-06
# 2 <class 'layers.Linear'> , mean (abs) grad: 3.61e-07 ; std: 4.55e-07
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 8.85e-08 ; std: 1.12e-07
# 0 <class 'layers.Linear'> , mean (abs) grad: 8.88e-09 ; std: 1.11e-08
#
# Epoch 0... (Train/Test) NLL: 2.317/2.306	Accuracy: 0.103/0.103
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.96e-03; W_std = 9.99e-03 | b_mean (abs) = 3.29e-04; b_std = 1.68e-04
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.18e-03; W_std = 1.00e-02 | b_mean (abs) = 4.12e-03; b_std = 6.56e-04
# 3 <class 'layers.Sigmoid'> , coeff: No coeff
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.12e-02; W_std = 1.00e-02 | b_mean (abs) = 1.81e-02; b_std = 8.19e-04
# 5 <class 'layers.Sigmoid'> , coeff: No coeff
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.62e-03; W_std = 9.54e-03 | b_mean (abs) = 1.04e-02; b_std = 1.22e-02
# 7 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 7 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.63e-03 ; std: 9.39e-03
# 6 <class 'layers.Linear'> , mean (abs) grad: 2.24e-04 ; std: 2.81e-04
# 5 <class 'layers.Sigmoid'> , mean (abs) grad: 3.36e-05 ; std: 4.22e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.76e-05 ; std: 2.11e-05
# 3 <class 'layers.Sigmoid'> , mean (abs) grad: 4.37e-06 ; std: 5.26e-06
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.76e-06 ; std: 3.43e-06
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 6.74e-07 ; std: 8.36e-07
# 0 <class 'layers.Linear'> , mean (abs) grad: 5.78e-08 ; std: 8.81e-08
#
# Epoch 1... (Train/Test) NLL: 2.304/2.298	Accuracy: 0.107/0.114
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.11e-03; W_std = 1.02e-02 | b_mean (abs) = 6.56e-04; b_std = 2.10e-04
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.88e-03; W_std = 1.01e-02 | b_mean (abs) = 6.52e-03; b_std = 8.14e-04
# 3 <class 'layers.Sigmoid'> , coeff: No coeff
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.32e-02; W_std = 1.00e-02 | b_mean (abs) = 2.28e-02; b_std = 9.45e-04
# 5 <class 'layers.Sigmoid'> , coeff: No coeff
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 9.10e-03; W_std = 1.16e-02 | b_mean (abs) = 6.26e-02; b_std = 1.01e-01
# 7 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 7 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.62e-03 ; std: 9.38e-03
# 6 <class 'layers.Linear'> , mean (abs) grad: 3.00e-04 ; std: 3.78e-04
# 5 <class 'layers.Sigmoid'> , mean (abs) grad:
-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 8.23e-05 ; std: 4.48e-04
# Epoch 27... (Train/Test) NLL: 0.049/0.161	Accuracy: 0.987/0.960
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 6.00e-02; W_std = 8.37e-02 | b_mean (abs) = 1.02e-01; b_std = 8.44e-02
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.46e-02; W_std = 1.08e-01 | b_mean (abs) = 5.03e-01; b_std = 3.56e-01
# 3 <class 'layers.Sigmoid'> , coeff: No coeff
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.07e-02; W_std = 7.88e-02 | b_mean (abs) = 3.88e-01; b_std = 4.83e-02
# 5 <class 'layers.Sigmoid'> , coeff: No coeff
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.73e-01; W_std = 5.21e-01 | b_mean (abs) = 5.24e+00; b_std = 6.71e+00
# 7 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 7 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.45e-04 ; std: 1.19e-03
# 6 <class 'layers.Linear'> , mean (abs) grad: 2.58e-04 ; std: 1.51e-03
# 5 <class 'layers.Sigmoid'> , mean (abs) grad: 3.87e-05 ; std: 3.03e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 3.05e-04 ; std: 2.08e-03
# 3 <class 'layers.Sigmoid'> , mean (abs) grad: 7.02e-05 ; std: 4.89e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.52e-03 ; std: 7.70e-03
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 3.08e-05 ; std: 5.00e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.18e-04 ; std: 6.42e-04
#
# Epoch 28... (Train/Test) NLL: 0.045/0.163	Accuracy: 0.988/0.962
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 6.06e-02; W_std = 8.47e-02 | b_mean (abs) = 1.03e-01; b_std = 8.49e-02
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.52e-02; W_std = 1.09e-01 | b_mean (abs) = 5.05e-01; b_std = 3.57e-01
# 3 <class 'layers.Sigmoid'> , coeff: No coeff
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.11e-02; W_std = 7.95e-02 | b_mean (abs) = 3.89e-01; b_std = 4.89e-02
# 5 <class 'layers.Sigmoid'> , coeff: No coeff
# 6 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.74e-01; W_std = 5.24e-01 | b_mean (abs) = 5.25e+00; b_std = 6.72e+00
# 7 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 7 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 9.01e-05 ; std: 5.51e-04
# 6 <class 'layers.Linear'> , mean (abs) grad: 1.58e-04 ; std: 8.45e-04
# 5 <class 'layers.Sigmoid'> , mean (abs) grad: 1.59e-05 ; std: 1.66e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.58e-04 ; std: 8.27e-04
# 3 <class 'layers.Sigmoid'> , mean (abs) grad: 3.61e-05 ; std: 1.93e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 6.16e-04 ; std: 2.79e-03
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 1.64e-05 ; std: 1.85e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 4.54e-05 ; std: 1.98e-04
#
# Epoch 29... (Train/Test) NLL: 0.041/0.157	Accuracy: 0.990/0.964
#
# Best for test: 0.9638578274760383

# %% [markdown]
# * Последний линейный слой слабо опирается на обучающую выборку, а имеет очень большие коэффициенты и предсказывает сам. Это следствие производной сигмоиды. Сигмоида вблизи 0 практически линейна, т.е. мы просто увеличиваем количество линейных коэффициентов => шума

# %% [markdown]
# *Уменьшение количества слоев*

# %%
# Малая нейронная сеть
network_small = NeuralNetwork([layers.Linear(784, 100), layers.Sigmoid(),
                               layers.Linear(100, 10), layers.SoftMax_NLLLoss()])
train(network_small, 20, 0.1, True)
# Out:
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.98e-03; W_std = 1.00e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.90e-03; W_std = 9.93e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 3 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 3 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.62e-03 ; std: 9.37e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.30e-04 ; std: 2.89e-04
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 5.63e-05 ; std: 7.08e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 5.58e-06 ; std: 7.01e-06
#
# Epoch 0... (Train/Test) NLL: 0.450/0.222	Accuracy: 0.870/0.936
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.93e-02; W_std = 2.77e-02 | b_mean (abs) = 8.05e-03; b_std = 9.95e-03
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.28e-01; W_std = 2.67e-01 | b_mean (abs) = 1.86e-02; b_std = 2.35e-02
# 3 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 3 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 4.87e-04 ; std: 2.41e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 6
-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.69e-05 ; std: 5.89e-05
#
# Epoch 16... (Train/Test) NLL: 0.029/0.073	Accuracy: 0.995/0.977
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.29e-02; W_std = 6.47e-02 | b_mean (abs) = 2.92e-02; b_std = 3.53e-02
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.22e-01; W_std = 6.32e-01 | b_mean (abs) = 6.44e-02; b_std = 7.53e-02
# 3 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 3 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.41e-05 ; std: 1.82e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.17e-04 ; std: 3.58e-04
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 7.60e-06 ; std: 3.69e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.11e-05 ; std: 3.58e-05
#
# Epoch 17... (Train/Test) NLL: 0.027/0.074	Accuracy: 0.995/0.978
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.36e-02; W_std = 6.57e-02 | b_mean (abs) = 2.94e-02; b_std = 3.56e-02
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.31e-01; W_std = 6.43e-01 | b_mean (abs) = 6.63e-02; b_std = 7.71e-02
# 3 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 3 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.44e-05 ; std: 6.74e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 5.05e-05 ; std: 1.46e-04
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 3.64e-06 ; std: 1.71e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 5.17e-06 ; std: 1.74e-05
#
# Epoch 18... (Train/Test) NLL: 0.025/0.074	Accuracy: 0.996/0.977
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.43e-02; W_std = 6.67e-02 | b_mean (abs) = 3.00e-02; b_std = 3.61e-02
# 1 <class 'layers.Sigmoid'> , coeff: No coeff
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.40e-01; W_std = 6.55e-01 | b_mean (abs) = 6.86e-02; b_std = 7.94e-02
# 3 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 3 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.42e-04 ; std: 2.56e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.27e-03 ; std: 5.90e-03
# 1 <class 'layers.Sigmoid'> , mean (abs) grad: 6.53e-05 ; std: 4.25e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.00e-04 ; std: 4.51e-04
#
# Epoch 19... (Train/Test) NLL: 0.023/0.070	Accuracy: 0.996/0.978
#
# Best for test: 0.978035143769968

# %% [markdown]
# * Малой нейронной сети просто не хватает коэффициентов для улучшения качества

# %% [markdown]
# ** Промежуточные выводы **
# В нейронных сетях с большим количеством скрытых слоев несигмоидные нелинейности лучше. Малой нейронной сети просто не хватает коэффициентов для улучшения качества

# %% [markdown]
# ### Часть 3: Предобработка данных

# %%
#Сеть - лучшая из обученных ранее
network_relu_fixed = NeuralNetwork([layers.Linear(784, 100), layers.ReLU(fixed=True), layers.Linear(100, 100), 
                                    layers.ReLU(fixed=True), layers.Linear(100, 10), layers.SoftMax_NLLLoss()])

# %%
#Используем blur.
train(network_relu_fixed, 20, 0.05, verbose=True, blur=1.0, rad=5, central=3)
# Out:
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.96e-03; W_std = 9.97e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.06e-03; W_std = 1.01e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.02e-03; W_std = 1.01e-02 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.63e-03 ; std: 9.38e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.42e-04 ; std: 3.01e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.25e-04 ; std: 2.02e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.61e-05 ; std: 2.05e-05
# 1 <class 'layers.ReLU'> , mean (abs) grad: 8.31e-06 ; std: 1.42e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.10e-06 ; std: 1.41e-06
#
# Epoch 0... (Train/Test) NLL: 0.627/0.195	Accuracy: 0.793/0.942
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.34e-02; W_std = 1.87e-02 | b_mean (abs) = 4.40e-03; b_std = 5.51e-03
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.57e-02; W_std = 3.65e-02 | b_mean (abs) = 1.49e-02; b_std = 1.35e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 8.97e-02; W_std = 1.20e-01 | b_mean (abs) = 1.15e-01; b_std = 1.35e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.83e-04 ; std: 2.02e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.60e-04 ; std: 7.69e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.26e-04 ; std: 7.07e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.83e-04 ; std: 9.84e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 9.52e-05 ; std: 6.40e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 4.69e-05 ; std: 2.41e-04
#
# Epoch 1... (Train/Test) NLL: 0.159/0.122	Accuracy: 0.952/0.965
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.58e-02; W_std = 2.30e-02 | b_mean (abs) = 5.64e-03; b_std = 7.29e-03
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.12e-02; W_std = 4.38e-02 | b_mean (abs) = 1.50e-02; b_std = 1.57e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.04e-01; W_std = 1.39e-01 | b_mean (abs) = 1.12e-01; b_std = 1.31e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.64e-04 ; std: 3.22e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 3.80e-04 ; std: 1.49e-03
# 3 <class 'layers.ReLU'> , mean (abs) grad: 2.58e-04 ; std: 1.18e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.76e-04 ; std: 1.79e-03
# 1 <class 'layers.ReLU'> , mean (abs) grad: 2.25e-04 ; std: 1.17e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.18e-04 ; std: 5.25e-04
#
# Epoch 2... (Train/Test) NLL: 0.108/0.102	Accuracy: 0.967/0.970
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.76e-02; W_std = 2.60e-02 | b_mean (abs) = 7.23e-03; b_std = 9.18e-03
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.51e-02; W_std = 4.89e-02 | b_mean (abs) = 1.67e-02; b_std = 1.86e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.13e-01; W_std = 1.50e-01 | b_mean (abs) = 1.10e-01; b_std = 1.30e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.27e-04 ; std: 1.60e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.17e-04 ; std: 7.54e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.53e-04 ; std: 6.19e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 3.04e-04 ; std: 1.01e-03
# 1 <class 'layers.ReLU'> , mean (abs) grad: 1.49e-04 ; std: 6.74e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 8.72e-05 ; std: 3.15e-04
#
# Epoch 3... (Train/Test) NLL: 0.082/0.090	Accuracy: 0.975/0.974
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.91e-02; W_std = 2.85e-02 | b_mean (abs) = 8.25e-03; b_std = 1.03e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.80e-02; W_std = 5.28e-02 | b_mean (abs) = 1.86e-02; b_std = 2.13e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.19e-01; W_std = 1.59e-01 | b_mean (abs) = 1.08e-01; b_std = 1.31e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.40e-05 ; std: 1.89e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.42e-05 ; std: 8.50e-05
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.71e-05 ; std: 7.41e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 3.60e-05 ; std: 1.26e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 1.62e-05 ; std: 7.63e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 9.48e-06 ; std: 3.53e-05
#
# Epoch 4... (Train/Test) NLL: 0.065/0.081	Accuracy: 0.980/0.975
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.05e-02; W_std = 3.06e-02 | b_mean (abs) = 9.45e-03; b_std = 1.14e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.05e-02; W_std = 5.62e-02 | b_mean (abs) = 2.00e-02; b_std = 2.35e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.25e-01; W_std = 1.66e-01 | b_mean (abs) = 1.08e-01; b_std = 1.32e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.57e-04 ; std: 2.23e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 3.05e-04 ; std: 1.14e-03
# 3 <class 'layers.ReLU'> , mean (abs) grad: 2.20e-04 ; std: 9.65e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.81e-04 ; std: 1.77e-03
# 1 <class 'layers.ReLU'> , mean (abs) grad: 2.07e-04 ; std: 1.10e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.25e-04 ; std: 5.33e-04
#
# Epoch 5... (Train/Test) NLL: 0.053/0.079	Accuracy: 0.983/0.976
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.16e-02; W_std = 3.24e-02 | b_mean (abs) = 1.06e-02; b_std = 1.29e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.26e-02; W_std = 5.91e-02 | b_mean (abs) = 2.14e-02; b_std = 2.57e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.30e-01; W_std = 1.72e-01 | b_mean (abs) = 1.06e-01; b_std = 1.32e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 8.68e-05 ; std: 6.35e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 6.91e-05 ; std: 3.15e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 4.69e-05 ; std: 2.66e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.11e-04 ; std: 4.85e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 4.82e-05 ; std: 3.13e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 3.07e-05 ; std: 1.56e-04
#
# Epoch 6... (Train/Test) NLL: 0.043/0.085	Accuracy: 0.987/0.976
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.26e-02; W_std = 3.40e-02 | b_mean (abs) = 1.16e-02; b_std = 1.38e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.46e-02; W_std = 6.17e-02 | b_mean (abs) = 2.27e-02; b_std = 2.73e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1
-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.67e-01; W_std = 2.19e-01 | b_mean (abs) = 1.10e-01; b_std = 1.37e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.68e-07 ; std: 6.71e-06
# 4 <class 'layers.Linear'> , mean (abs) grad: 6.72e-07 ; std: 4.64e-06
# 3 <class 'layers.ReLU'> , mean (abs) grad: 4.13e-07 ; std: 3.58e-06
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.19e-06 ; std: 8.29e-06
# 1 <class 'layers.ReLU'> , mean (abs) grad: 5.45e-07 ; std: 5.50e-06
# 0 <class 'layers.Linear'> , mean (abs) grad: 4.42e-07 ; std: 3.44e-06
#
# Epoch 18... (Train/Test) NLL: 0.003/0.101	Accuracy: 1.000/0.978
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.89e-02; W_std = 4.39e-02 | b_mean (abs) = 1.55e-02; b_std = 1.80e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.81e-02; W_std = 7.93e-02 | b_mean (abs) = 2.89e-02; b_std = 3.53e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.69e-01; W_std = 2.22e-01 | b_mean (abs) = 1.11e-01; b_std = 1.37e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.16e-07 ; std: 2.99e-06
# 4 <class 'layers.Linear'> , mean (abs) grad: 3.47e-07 ; std: 1.96e-06
# 3 <class 'layers.ReLU'> , mean (abs) grad: 2.57e-07 ; std: 1.78e-06
# 2 <class 'layers.Linear'> , mean (abs) grad: 7.52e-07 ; std: 4.24e-06
# 1 <class 'layers.ReLU'> , mean (abs) grad: 3.35e-07 ; std: 2.55e-06
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.72e-07 ; std: 1.64e-06
#
# Epoch 19... (Train/Test) NLL: 0.001/0.091	Accuracy: 1.000/0.980
#
# Best for test: 0.9803314696485623
# e:\c_folders\users\fen\anaconda2\envs\py36\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# * Размытие только на обучающей выборке не улучшает результат. Попробуем также делать размытие на тесте

# %%
train(network_relu_fixed, 20, 0.05, verbose=True, blur=1.0, rad=5, central=3, blur_test=True)
# Out:
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.97e-03; W_std = 9.98e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.80e-03; W_std = 9.76e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 7.91e-03; W_std = 9.81e-03 | b_mean (abs) = 0.00e+00; b_std = 0.00e+00
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.62e-03 ; std: 9.37e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.38e-04 ; std: 2.96e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.42e-04 ; std: 2.21e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.62e-05 ; std: 2.07e-05
# 1 <class 'layers.ReLU'> , mean (abs) grad: 8.98e-06 ; std: 1.48e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.18e-06 ; std: 1.49e-06
#
# Epoch 0... (Train/Test) NLL: 0.610/0.199	Accuracy: 0.800/0.941
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.34e-02; W_std = 1.87e-02 | b_mean (abs) = 4.31e-03; b_std = 4.85e-03
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.62e-02; W_std = 3.66e-02 | b_mean (abs) = 1.31e-02; b_std = 1.24e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 9.00e-02; W_std = 1.19e-01 | b_mean (abs) = 9.84e-02; b_std = 1.23e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.09e-03 ; std: 3.86e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 6.16e-04 ; std: 1.49e-03
# 3 <class 'layers.ReLU'> , mean (abs) grad: 4.59e-04 ; std: 1.25e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 6.32e-04 ; std: 1.52e-03
# 1 <class 'layers.ReLU'> , mean (abs) grad: 3.98e-04 ; std: 1.20e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.91e-04 ; std: 5.20e-04
#
# Epoch 1... (Train/Test) NLL: 0.164/0.130	Accuracy: 0.951/0.959
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.65e-02; W_std = 2.50e-02 | b_mean (abs) = 5.78e-03; b_std = 7.53e-03
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.18e-02; W_std = 4.41e-02 | b_mean (abs) = 1.46e-02; b_std = 1.46e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.04e-01; W_std = 1.39e-01 | b_mean (abs) = 9.26e-02; b_std = 1.10e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.13e-04 ; std: 2.45e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.21e-04 ; std: 1.11e-03
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.47e-04 ; std: 8.82e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.55e-04 ; std: 1.18e-03
# 1 <class 'layers.ReLU'> , mean (abs) grad: 1.33e-04 ; std: 7.79e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 6.54e-05 ; std: 3.46e-04
#
# Epoch 2... (Train/Test) NLL: 0.109/0.104	Accuracy: 0.968/0.968
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.83e-02; W_std = 2.77e-02 | b_mean (abs) = 6.79e-03; b_std = 9.06e-03
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.57e-02; W_std = 4.92e-02 | b_mean (abs) = 1.65e-02; b_std = 1.82e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.14e-01; W_std = 1.51e-01 | b_mean (abs) = 8.87e-02; b_std = 1.03e-01
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.50e-04 ; std: 1.47e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.89e-04 ; std: 7.15e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.41e-04 ; std: 6.02e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.61e-04 ; std: 9.71e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 1.34e-04 ; std: 6.36e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 7.32e-05 ; std: 3.29e-04
#
# Epoch 3... (Train/Test) NLL: 0.082/0.096	Accuracy: 0.975/0.970
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.98e-02; W_std = 3.00e-02 | b_mean (abs) = 8.02e-03; b_std = 1.05e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.86e-02; W_std = 5.32e-02 | b_mean (abs) = 1.80e-02; b_std = 2.08e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.20e-01; W_std = 1.60e-01 | b_mean (abs) = 8.44e-02; b_std = 9.91e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.83e-04 ; std: 1.19e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.36e-04 ; std: 5.91e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 9.68e-05 ; std: 4.86e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.80e-04 ; std: 6.87e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 8.73e-05 ; std: 4.56e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 5.14e-05 ; std: 2.33e-04
#
# Epoch 4... (Train/Test) NLL: 0.065/0.084	Accuracy: 0.979/0.976
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.10e-02; W_std = 3.19e-02 | b_mean (abs) = 9.45e-03; b_std = 1.17e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.10e-02; W_std = 5.64e-02 | b_mean (abs) = 2.03e-02; b_std = 2.43e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.25e-01; W_std = 1.66e-01 | b_mean (abs) = 8.26e-02; b_std = 9.75e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 2.63e-04 ; std: 1.86e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.02e-04 ; std: 9.05e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.33e-04 ; std: 7.23e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.73e-04 ; std: 1.13e-03
# 1 <class 'layers.ReLU'> , mean (abs) grad: 1.17e-04 ; std: 6.69e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 7.31e-05 ; std: 3.36e-04
#
# Epoch 5... (Train/Test) NLL: 0.051/0.110	Accuracy: 0.984/0.968
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.21e-02; W_std = 3.36e-02 | b_mean (abs) = 1.03e-02; b_std = 1.29e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.33e-02; W_std = 5.94e-02 | b_mean (abs) = 2.19e-02; b_std = 2.66e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.30e-01; W_std = 1.73e-01 | b_mean (abs) = 8.16e-02; b_std = 9.73e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.93e-04 ; std: 1.06e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 1.51e-04 ; std: 5.67e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.11e-04 ; std: 5.00e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 2.56e-04 ; std: 8.78e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 1.11e-04 ; std: 5.22e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 6.11e-05 ; std: 2.32e-04
#
# Epoch 6... (Train/Test) NLL: 0.044/0.104	Accuracy: 0.986/0.970
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.31e-02; W_std = 3.51e-02 | b_mean (abs) = 1.11e-02; b_std = 1.34e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.52e-02; W_std = 6.19e-02 | b_mean (abs) = 2.32e-02; b_std = 2.83e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.34e-01; W_std = 1.78e-01 | b_mean (abs) = 7.87e-02; b_std = 9.62e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 4.55e-04 ; std: 2.22e-03
# 4 <class 'layers.Linear'> , mean (abs) grad: 3.64e-04 ; std: 1.23e-03
# 3 <class 'layers.ReLU'> , mean (abs) grad: 2.57e-04 ; std: 1.01e-03
# 2 <class 'layers.Linear'> , mean (abs) grad: 5.75e-04 ; std: 1.89e-03
# 1 <class 'layers.ReLU'> , mean (abs) grad: 2.74e-04 ; std: 1.29e-03
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.85e-04 ; std: 7.29e-04
#
# Epoch 7... (Train/Test) NLL: 0.037/0.090	Accuracy: 0.988/0.975
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.40e-02; W_std = 3.65e-02 | b_mean (abs) = 1.13e-02; b_std = 1.34e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 4.69e-02; W_std = 6.43e-02 | b_mean (abs) = 2.44e-02; b_std = 3.00e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1
-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.25e-05 ; std: 9.21e-05
#
# Epoch 13... (Train/Test) NLL: 0.018/0.087	Accuracy: 0.994/0.979
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.84e-02; W_std = 4.34e-02 | b_mean (abs) = 1.38e-02; b_std = 1.56e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.59e-02; W_std = 7.63e-02 | b_mean (abs) = 2.95e-02; b_std = 3.64e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.57e-01; W_std = 2.06e-01 | b_mean (abs) = 7.69e-02; b_std = 9.65e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 1.99e-05 ; std: 1.48e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 2.09e-05 ; std: 9.39e-05
# 3 <class 'layers.ReLU'> , mean (abs) grad: 1.49e-05 ; std: 7.76e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 4.09e-05 ; std: 1.68e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 1.82e-05 ; std: 1.10e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 1.26e-05 ; std: 6.33e-05
#
# Epoch 14... (Train/Test) NLL: 0.013/0.085	Accuracy: 0.996/0.981
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.88e-02; W_std = 4.41e-02 | b_mean (abs) = 1.39e-02; b_std = 1.56e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.69e-02; W_std = 7.76e-02 | b_mean (abs) = 3.01e-02; b_std = 3.71e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.59e-01; W_std = 2.10e-01 | b_mean (abs) = 7.74e-02; b_std = 9.66e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 3.78e-05 ; std: 4.09e-04
# 4 <class 'layers.Linear'> , mean (abs) grad: 3.30e-05 ; std: 2.23e-04
# 3 <class 'layers.ReLU'> , mean (abs) grad: 2.48e-05 ; std: 2.05e-04
# 2 <class 'layers.Linear'> , mean (abs) grad: 6.82e-05 ; std: 4.35e-04
# 1 <class 'layers.ReLU'> , mean (abs) grad: 3.18e-05 ; std: 2.93e-04
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.16e-05 ; std: 1.69e-04
#
# Epoch 15... (Train/Test) NLL: 0.010/0.088	Accuracy: 0.997/0.980
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.92e-02; W_std = 4.47e-02 | b_mean (abs) = 1.43e-02; b_std = 1.61e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.77e-02; W_std = 7.87e-02 | b_mean (abs) = 3.04e-02; b_std = 3.75e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.62e-01; W_std = 2.12e-01 | b_mean (abs) = 7.81e-02; b_std = 9.68e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 4.02e-06 ; std: 3.99e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 4.62e-06 ; std: 2.88e-05
# 3 <class 'layers.ReLU'> , mean (abs) grad: 3.49e-06 ; std: 2.54e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 9.84e-06 ; std: 5.69e-05
# 1 <class 'layers.ReLU'> , mean (abs) grad: 3.88e-06 ; std: 3.33e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 2.91e-06 ; std: 1.97e-05
#
# Epoch 16... (Train/Test) NLL: 0.011/0.094	Accuracy: 0.997/0.979
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 2.97e-02; W_std = 4.53e-02 | b_mean (abs) = 1.47e-02; b_std = 1.63e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.84e-02; W_std = 7.98e-02 | b_mean (abs) = 3.08e-02; b_std = 3.82e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.63e-01; W_std = 2.15e-01 | b_mean (abs) = 7.82e-02; b_std = 9.67e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 6.55e-06 ; std: 5.21e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 7.03e-06 ; std: 3.48e-05
# 3 <class 'layers.ReLU'> , mean (abs) grad: 4.29e-06 ; std: 2.45e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.13e-05 ; std: 5.00e-05
# 1 <class 'layers.ReLU'> , mean (abs) grad: 4.55e-06 ; std: 2.95e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 3.26e-06 ; std: 1.64e-05
# Epoch 17... (Train/Test) NLL: 0.006/0.097	Accuracy: 0.998/0.978
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.00e-02; W_std = 4.57e-02 | b_mean (abs) = 1.50e-02; b_std = 1.70e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.91e-02; W_std = 8.07e-02 | b_mean (abs) = 3.11e-02; b_std = 3.86e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.65e-01; W_std = 2.17e-01 | b_mean (abs) = 7.86e-02; b_std = 9.70e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 5.00e-06 ; std: 5.73e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 6.51e-06 ; std: 4.34e-05
# 3 <class 'layers.ReLU'> , mean (abs) grad: 4.22e-06 ; std: 3.47e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.27e-05 ; std: 8.33e-05
# 1 <class 'layers.ReLU'> , mean (abs) grad: 5.21e-06 ; std: 4.64e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 3.50e-06 ; std: 2.72e-05
#
# Epoch 18... (Train/Test) NLL: 0.007/0.108	Accuracy: 0.998/0.978
# 0 <class 'layers.Linear'> , coeff: W_mean (abs) = 3.03e-02; W_std = 4.62e-02 | b_mean (abs) = 1.47e-02; b_std = 1.66e-02
# 1 <class 'layers.ReLU'> , coeff: 1.00e-01
# 2 <class 'layers.Linear'> , coeff: W_mean (abs) = 5.98e-02; W_std = 8.16e-02 | b_mean (abs) = 3.13e-02; b_std = 3.86e-02
# 3 <class 'layers.ReLU'> , coeff: 1.00e-01
# 4 <class 'layers.Linear'> , coeff: W_mean (abs) = 1.67e-01; W_std = 2.20e-01 | b_mean (abs) = 7.91e-02; b_std = 9.75e-02
# 5 <class 'layers.SoftMax_NLLLoss'> , coeff: No coeff
#
# 5 <class 'layers.SoftMax_NLLLoss'> , mean (abs) grad: 4.45e-06 ; std: 3.46e-05
# 4 <class 'layers.Linear'> , mean (abs) grad: 5.72e-06 ; std: 2.72e-05
# 3 <class 'layers.ReLU'> , mean (abs) grad: 3.97e-06 ; std: 2.34e-05
# 2 <class 'layers.Linear'> , mean (abs) grad: 1.25e-05 ; std: 5.76e-05
# 1 <class 'layers.ReLU'> , mean (abs) grad: 4.73e-06 ; std: 3.11e-05
# 0 <class 'layers.Linear'> , mean (abs) grad: 3.39e-06 ; std: 1.84e-05
#
# Epoch 19... (Train/Test) NLL: 0.004/0.090	Accuracy: 0.999/0.982
#
# Best for test: 0.9818290734824281
# e:\c_folders\users\fen\anaconda2\envs\py36\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# * Случайное размытие на тесте улучшает качество (!)

# %%
#Добавим в датасет 2 поворота
def GetTransform(deg):
    if deg < 0:
        deg = 360.0+deg
    return transforms.Compose([transforms.RandomRotation(deg),
                               transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

transform0 = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

train_with_transforms = ConcatDataset([MNIST('.', train=True, download=True, transform=transform0),
                                       MNIST('.', train=True, download=True, transform=GetTransform(3)),
                                       MNIST('.', train=True, download=True, transform=GetTransform(-3))])
train_loader_transforms = DataLoader(train_with_transforms, batch_size=4096, shuffle=True)

# %%
network_relu_fixed = NeuralNetwork([layers.Linear(784, 100), layers.ReLU(fixed=True), layers.Linear(100, 100), 
                                    layers.ReLU(fixed=True), layers.Linear(100, 10), layers.SoftMax_NLLLoss()])
train(network_relu_fixed, 100, 0.3, verbose=False, train=train_loader_transforms, blur=1.0, rad=5, central=3, blur_test=True)
# Out:
# Epoch 0... (Train/Test) NLL: 2.227/1.813	Accuracy: 0.182/0.362
#
# Epoch 1... (Train/Test) NLL: 1.554/0.819	Accuracy: 0.463/0.723
#
# Epoch 2... (Train/Test) NLL: 1.001/0.496	Accuracy: 0.664/0.865
#
# Epoch 3... (Train/Test) NLL: 0.834/0.380	Accuracy: 0.728/0.895
#
# Epoch 4... (Train/Test) NLL: 0.719/0.390	Accuracy: 0.765/0.876
#
# Epoch 5... (Train/Test) NLL: 0.652/0.326	Accuracy: 0.786/0.900
#
# Epoch 6... (Train/Test) NLL: 0.593/0.454	Accuracy: 0.805/0.848
#
# Epoch 7... (Train/Test) NLL: 0.533/0.235	Accuracy: 0.825/0.932
#
# Epoch 8... (Train/Test) NLL: 0.482/0.202	Accuracy: 0.846/0.943
#
# Epoch 9... (Train/Test) NLL: 0.462/0.279	Accuracy: 0.854/0.913
#
# Epoch 10... (Train/Test) NLL: 0.438/0.168	Accuracy: 0.863/0.950
#
# Epoch 11... (Train/Test) NLL: 0.378/0.161	Accuracy: 0.883/0.950
#
# Epoch 12... (Train/Test) NLL: 0.358/0.151	Accuracy: 0.888/0.956
#
# Epoch 13... (Train/Test) NLL: 0.323/0.144	Accuracy: 0.900/0.955
#
# Epoch 14... (Train/Test) NLL: 0.350/0.229	Accuracy: 0.893/0.931
#
# Epoch 15... (Train/Test) NLL: 0.300/0.140	Accuracy: 0.908/0.958
#
# Epoch 16... (Train/Test) NLL: 0.373/0.147	Accuracy: 0.889/0.956
#
# Epoch 17... (Train/Test) NLL: 0.271/0.140	Accuracy: 0.918/0.957
#
# Epoch 18... (Train/Test) NLL: 0.259/0.120	Accuracy: 0.920/0.964
#
# Epoch 19... (Train/Test) NLL: 0.247/0.116	Accuracy: 0.924/0.966
#
# Epoch 20... (Train/Test) NLL: 0.248/0.113	Accuracy: 0.923/0.966
#
# Epoch 21... (Train/Test) NLL: 0.219/0.119	Accuracy: 0.933/0.964
#
# Epoch 22... (Train/Test) NLL: 0.251/0.119	Accuracy: 0.923/0.965
#
# Epoch 23... (Train/Test) NLL: 0.216/0.106	Accuracy: 0.934/0.970
#
# Epoch 24... (Train/Test) NLL: 0.209/0.109	Accuracy: 0.936/0.967
#
# Epoch 25... (Train/Test) NLL: 0.204/0.106	Accuracy: 0.938/0.968
#
# Epoch 26... (Train/Test) NLL: 0.196/0.103	Accuracy: 0.940/0.970
#
# Epoch 27... (Train/Test) NLL: 0.721/0.184	Accuracy: 0.834/0.947
#
# Epoch 28... (Train/Test) NLL: 0.296/0.130	Accuracy: 0.909/0.963
#
# Epoch 29... (Train/Test) NLL: 0.233/0.119	Accuracy: 0.928/0.964
#
# Epoch 30... (Train/Test) NLL: 0.208/0.107	Accuracy: 0.937/0.968
#
# Epoch 31... (Train/Test) NLL: 0.204/0.130	Accuracy: 0.938/0.960
#
# Epoch 32... (Train/Test) NLL: 0.192/0.100	Accuracy: 0.942/0.971
#
# Epoch 33... (Train/Test) NLL: 0.183/0.100	Accuracy: 0.945/0.970
#
# Epoch 34... (Train/Test) NLL: 0.273/1.667	Accuracy: 0.922/0.650
#
# Epoch 35... (Train/Test) NLL: 0.271/0.102	Accuracy: 0.922/0.968
#
# Epoch 36... (Train/Test) NLL: 0.180/0.094	Accuracy: 0.946/0.973
#
# Epoch 37... (Train/Test) NLL: 0.171/0.094	Accuracy: 0.949/0.972
#
# Epoch 38... (Train/Test) NLL: 0.166/0.094	Accuracy: 0.950/0.972
#
# Epoch 39... (Train/Test) NLL: 0.161/0.090	Accuracy: 0.951/0.974
#
# Epoch 40... (Train/Test) NLL: 0.157/0.090	Accuracy: 0.953/0.974
#
# Epoch 41... (Train/Test) NLL: 0.152/0.088	Accuracy: 0.954/0.975
#
# Epoch 42... (Train/Test) NLL: 0.151/0.090	Accuracy: 0.955/0.973
#
# Epoch 43... (Train/Test) NLL: 0.149/0.091	Accuracy: 0.955/0.973
#
# Epoch 44... (Train/Test) NLL: 0.148/0.088	Accuracy: 0.956/0.974
#
# Epoch 45... (Train/Test) NLL: 0.145/0.086	Accuracy: 0.957/0.974
#
# Epoch 46... (Train/Test) NLL: 0.140/0.087	Accuracy: 0.958/0.974
#
# Epoch 47... (Train/Test) NLL: 0.142/0.089	Accuracy: 0.957/0.974
#
# Epoch 48... (Train/Test) NLL: 0.138/0.088	Accuracy: 0.958/0.974
#
# Epoch 49... (Train/Test) NLL: 0.134/0.088	Accuracy: 0.960/0.974
#
# Epoch 50... (Train/Test) NLL: 0.134/0.087	Accuracy: 0.960/0.975
#
# Epoch 51... (Train/Test) NLL: 0.137/0.088	Accuracy: 0.959/0.973
#
# Epoch 52... (Train/Test) NLL: 0.130/0.089	Accuracy: 0.961/0.974
#
# Epoch 53... (Train/Test) NLL: 0.414/0.108	Accuracy: 0.892/0.968
#
# Epoch 54... (Train/Test) NLL: 0.164/0.088	Accuracy: 0.950/0.975
#
# Epoch 55... (Train/Test) NLL: 0.142/0.084	Accuracy: 0.957/0.976
#
# Epoch 56... (Train/Test) NLL: 0.133/0.082	Accuracy: 0.960/0.975
#
# Epoch 57... (Train/Test) NLL: 0.128/0.081	Accuracy: 0.961/0.976
#
# Epoch 58... (Train/Test) NLL: 0.125/0.082	Accuracy: 0.963/0.975
#
# Epoch 59... (Train/Test) NLL: 0.124/0.081	Accuracy: 0.963/0.975
#
# Epoch 60... (Train/Test) NLL: 0.122/0.080	Accuracy: 0.964/0.977
#
# Epoch 61... (Train/Test) NLL: 0.120/0.079	Accuracy: 0.964/0.977
#
# Epoch 62... (Train/Test) NLL: 0.118/0.078	Accuracy: 0.965/0.975
#
# Epoch 63... (Train/Test) NLL: 0.116/0.081	Accuracy: 0.966/0.974
#
# Epoch 64... (Train/Test) NLL: 0.114/0.080	Accuracy: 0.966/0.975
#
# Epoch 65... (Train/Test) NLL: 0.113/0.079	Accuracy: 0.966/0.976
#
# Epoch 66... (Train/Test) NLL: 0.114/0.079	Accuracy: 0.966/0.975
#
# Epoch 67... (Train/Test) NLL: 0.112/0.079	Accuracy: 0.967/0.977
#
# Epoch 68... (Train/Test) NLL: 0.112/0.079	Accuracy: 0.967/0.976
#
# Epoch 69... (Train/Test) NLL: 0.109/0.077	Accuracy: 0.968/0.976
#
# Epoch 70... (Train/Test) NLL: 0.108/0.080	Accuracy: 0.968/0.976
#
# Epoch 71... (Train/Test) NLL: 0.108/0.078	Accuracy: 0.968/0.976
#
# Epoch 72... (Train/Test) NLL: 0.107/0.078	Accuracy: 0.969/0.976
#
# Epoch 73... (Train/Test) NLL: 0.106/0.077	Accuracy: 0.969/0.977
#
# Epoch 74... (Train/Test) NLL: 0.105/0.083	Accuracy: 0.969/0.976
#
# Epoch 75... (Train/Test) NLL: 0.106/0.077	Accuracy: 0.968/0.977
#
# Epoch 76... (Train/Test) NLL: 0.104/0.080	Accuracy: 0.970/0.976
#
# Epoch 77... (Train/Test) NLL: 0.102/0.077	Accuracy: 0.970/0.977
#
# Epoch 78... (Train/Test) NLL: 0.104/0.078	Accuracy: 0.969/0.976
#
# Epoch 79... (Train/Test) NLL: 0.100/0.079	Accuracy: 0.971/0.976
#
# Epoch 80... (Train/Test) NLL: 0.101/0.077	Accuracy: 0.971/0.977
#
# Epoch 81... (Train/Test) NLL: 0.100/0.077	Accuracy: 0.971/0.977
#
# Epoch 82... (Train/Test) NLL: 0.098/0.077	Accuracy: 0.971/0.977
#
# Epoch 83... (Train/Test) NLL: 0.098/0.077	Accuracy: 0.972/0.977
#
# Epoch 84... (Train/Test) NLL: 0.099/0.078	Accuracy: 0.971/0.976
#
# Epoch 85... (Train/Test) NLL: 0.097/0.074	Accuracy: 0.972/0.976
#
# Epoch 86... (Train/Test) NLL: 0.096/0.079	Accuracy: 0.972/0.976
#
# Epoch 87... (Train/Test) NLL: 0.095/0.076	Accuracy: 0.973/0.976
#
# Epoch 88... (Train/Test) NLL: 0.097/0.076	Accuracy: 0.972/0.978
#
# Epoch 89... (Train/Test) NLL: 0.094/0.077	Accuracy: 0.972/0.977
#
# Epoch 90... (Train/Test) NLL: 0.094/0.075	Accuracy: 0.972/0.977
#
# Epoch 91... (Train/Test) NLL: 0.093/0.074	Accuracy: 0.973/0.977
#
# Epoch 92... (Train/Test) NLL: 0.093/0.082	Accuracy: 0.973/0.975
#
# Epoch 93... (Train/Test) NLL: 0.092/0.078	Accuracy: 0.973/0.976
#
# Epoch 94... (Train/Test) NLL: 0.091/0.082	Accuracy: 0.974/0.975
#
# Epoch 95... (Train/Test) NLL: 0.091/0.076	Accuracy: 0.974/0.977
#
# Epoch 96... (Train/Test) NLL: 0.091/0.075	Accuracy: 0.974/0.977
#
# Epoch 97... (Train/Test) NLL: 0.091/0.077	Accuracy: 0.974/0.977
#
# Epoch 98... (Train/Test) NLL: 0.089/0.077	Accuracy: 0.974/0.977
#
# Epoch 99... (Train/Test) NLL: 0.089/0.077	Accuracy: 0.974/0.977
#
# Best for test: 0.9776357827476039
# e:\c_folders\users\fen\anaconda2\envs\py36\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# * Повороты не улучшают качество сходимости

# %% [markdown]
# ### Часть 4: Выводы
# Опишите полученные результаты: как влияют выбор нелинейности и предобработка данных на скорость сходимости и итоговое качество?

# %% [markdown]
# 1. Теоретически, ELU и ReLU лучше сигмоиды: они позволяют уменьшить затухание градиентов и увеличить зависимость последнего слоя от входных данных (избежать возрастания его коэффициентов), но на малых сетях это практически не заметно.
# 2. Однако уже на нейронных сетях среднего размера использование сигмоиды приводит к увеличению коэффициентов последних слоев вероятно как за счет затухания градиентов, так и (без специальной инициализации) за счет близости сигмоиды к линейной функции вблизи 0
# 3. Простое увеличение количества слоев не приводит к прямому повышению качества (вероятно, из-за переобучения сети). Снижение количества слоев также не увеличивает качества
# 4. Использование аугментации улучшает качество классификации, но требуемый тип аугментации зависит от специфики выборки
