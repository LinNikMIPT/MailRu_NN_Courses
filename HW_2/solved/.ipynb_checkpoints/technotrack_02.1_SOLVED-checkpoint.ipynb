# %% [markdown]
# ## Домашнее задание №2: Глубинные нейронные сети. Pytorch

# %% [markdown]
# ### Пожалуйста, заполните имя

# %%
STUDENT_NAME = "FirstName LastName" # For example, Fedor Petriaikin

# %%
# Включает режим проверки
try:
    import train_utils
    TEST_MODE = True
except:
    TEST_MODE = False

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from torch.nn import MSELoss, Sequential, Linear, Sigmoid, Tanh, NLLLoss
import torch.nn as nn
from torch import Tensor
# %matplotlib inline

# %% [markdown]
# **Не удаляйте клетки из этого jupyter-notebok! Это затруднит проверку!**
#
# В этом задании вам предстоит попробовать обучить нейронную сеть с помощью фреймворка Pytorch, изучить подходы к инициализации нейронных сетей и реализовать слои, улучшающие сходимость глубинных нейронных сетей.

# %% [markdown]
# ### Часть 3. Улучшение сходимости глубинных нейронных сетей
# **Dropout**

# %%
# Реализуйте функцию train для нашего задания (по аналогии с частью 1)
# Функция должна строить графики loss и accuracy для train и test
# Не забудьте сделать ravel!

def mnist_train_verbose(network, train_dataloader, test_dataloader, epochs):
    optimizer = torch.optim.Adam(network.parameters(), lr=0.001)
    loss = NLLLoss()
    ##### YOUR CODE HERE #####
    pass

# %% [markdown]
# Опять загрузим MNIST

# %%
from torchvision.datasets import MNIST

to_numpy = lambda x: x.numpy()
transform = transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                    ])
train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

train_loader_mnist = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader_mnist = DataLoader(test_dataset, batch_size=128, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to .\MNIST\raw\train-images-idx3-ubyte.gz
# 100.1%
# Extracting .\MNIST\raw\train-images-idx3-ubyte.gz to .\MNIST\raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to .\MNIST\raw\train-labels-idx1-ubyte.gz
# 113.5%
# Extracting .\MNIST\raw\train-labels-idx1-ubyte.gz to .\MNIST\raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to .\MNIST\raw\t10k-images-idx3-ubyte.gz
# 100.4%
# Extracting .\MNIST\raw\t10k-images-idx3-ubyte.gz to .\MNIST\raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to .\MNIST\raw\t10k-labels-idx1-ubyte.gz
# 180.4%
# Extracting .\MNIST\raw\t10k-labels-idx1-ubyte.gz to .\MNIST\raw
# Processing...
# Done!

# %%
# Тестовые батчи. Нарисуем их, а потом будем пропускать их через нейронную сеть
images_train, labels_train = next(iter(train_loader_mnist))

# %%
plt.figure(figsize=(6, 7))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(images_train.numpy()[i].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title(labels_train.numpy()[i])
    plt.axis('off')

# %% [markdown]
# Обучим обычную нейронную сеть:

# %%
network1 = nn.Sequential(nn.Linear(784, 100),
                         nn.ReLU(),
                         nn.Linear(100, 100),
                         nn.ReLU(),
                         nn.Linear(100, 10),
                         nn.LogSoftmax())

mnist_train_verbose(network1, train_loader_mnist, test_loader_mnist, 10)

# %%
# Проверка
if TEST_MODE:
    from importlib import reload
    reload(train_utils)
    train_utils.train(network1, train_loader_mnist, test_loader_mnist, 10, learning_rate=0.001, ravel_init=True,
                      need_accuracies=True)
# Out:
# Epoch 6... (Train/Test) Loss: 0.007/0.163
# Epoch 6... (Train/Test) Accuracies: 0.980/0.980

# %% [markdown]
# Реализуйте DropConnect.

# %%
# полезная функция: .bernoulli_(p)
# не забывайте делать requires_grad=False у маски
# Не забудьте заменить все вероятности на p при test-проходе!

class DropConnect(nn.Module):
    def __init__(self, input_dim, output_dim, p=0.5, mean=0, std=0.01):
        ##### YOUR CODE HERE #####
        super(DropConnect, self).__init__()
        self.weight = nn.Parameter(torch.Tensor(input_dim, output_dim).normal_(mean=mean, std=std), requires_grad=True)
        self.bias = nn.Parameter(torch.Tensor(1, output_dim).zero_(), requires_grad=True)
        self.p = p

    def forward(self, x):
        ##### YOUR CODE HERE #####
        if self.training:
            mask = torch.zeros(self.weight.size())+(1-self.p)
            mask = torch.bernoulli(mask)
        else:
            mask = torch.ones(self.weight.size())*self.p
        mask = torch.tensor(mask, requires_grad=False)
        output = torch.mm(x, self.weight*mask)+self.bias
        return output

# %% [markdown]
# Сравните графики обучения нейроных сетей:
# <i>
# 1. 784 -> 200 -> 200 -> 10 с ReLU и Dropout между всеми слоями
# 2. 784 -> 200 -> 200 -> 10 с ReLU DropConnect вместо всех линейных слоев
# </i>

# %%
##### YOUR CODE HERE #####
network2 = nn.Sequential(nn.Linear(784, 200),
                        nn.Dropout(0.5),
                        nn.ReLU(),
                        nn.Linear(200, 200),
                        nn.Dropout(0.5),
                        nn.ReLU(),
                        nn.Linear(200, 10),
                        nn.LogSoftmax())

if TEST_MODE:
    from importlib import reload
    reload(train_utils)
    train_utils.train(network2, train_loader_mnist, test_loader_mnist, 20, learning_rate=0.001, ravel_init=True,
                      need_accuracies=True)
# Out:
# Epoch 3... (Train/Test) Loss: 0.173/0.105
# Epoch 3... (Train/Test) Accuracies: 0.968/0.968

# %%
network3 = nn.Sequential(nn.Linear(784, 200),
                        nn.ReLU(),
                        DropConnect(200, 200, p=0.5),
                        nn.ReLU(),
                        DropConnect(200, 10, p=0.5),
                        nn.LogSoftmax())

train_utils.train(network3, train_loader_mnist, test_loader_mnist, 20, learning_rate=0.001, ravel_init=True,
                      need_accuracies=True)
# Out:
# Epoch 4... (Train/Test) Loss: 0.104/0.091
# Epoch 4... (Train/Test) Accuracies: 0.973/0.973
# ([0.61924496207283,
#   0.23537915598736134,
#   0.16392643382745004,
#   0.1295246043836257,
#   0.10397262450680932],
#  [0.23708281873524945,
#   0.15584048298718053,
#   0.12328735070562438,
#   0.10005264149247846,
#   0.09116641782324383])

# %% [markdown]
# *Выводы:*
#
# ...

# %% [markdown]
# **Нормализация**

# %% [markdown]
# Давайте рассмотрим Batch Normalization. Этот слой вычитает среднее и делит на стандартное отклонение. Среднее и дисперсия вычисляются по батчу независимо для каждого нейрона. У этого слоя есть две важные проблемы: его нельзя использовать при обучении с размером батча 1 и он делает элементы батча зависимыми. Давайте реализуем аналог батч нормализации: <a href=https://arxiv.org/pdf/1607.06450.pdf>Layer normalization</a>. В layer normalization среднее и дисперсия вычисляются по активациям нейронов, независимо для каждого объекта.

# %%
# полезные функции: .std(dim), .mean(dim)

class LayerNormalization(nn.Module):
    def forward(self, x):
        ##### YOUR CODE HERE #####
        means = x.mean(dim=1).view(x.shape[0], -1)
        stds = x.std(dim=1).view(x.shape[0], -1)
        output = (x - means) / stds
        return output

# %% [markdown]
# <i>
# 3.2 Сравните графики обучения нейроных сетей:
# 1. 784 -> 200 -> 200 -> 10 с ReLU и Batch normalization между всеми слоями
# 2. 784 -> 200 -> 200 -> 10 с ReLU и Layer normalization между всеми слоями
# </i>

# %%
# Не забудьте убрать bias при батч-нормализации
##### YOUR CODE HERE #####
network = nn.Sequential(nn.Linear(784, 200, bias=False),
                        nn.BatchNorm1d(200),
                        nn.ReLU(),
                        nn.Linear(200, 200, bias=False),
                        nn.BatchNorm1d(200),
                        nn.ReLU(),
                        nn.Linear(200, 10),
                        nn.LogSoftmax())
train_utils.train(network, train_loader_mnist, test_loader_mnist, 20, learning_rate=0.001, ravel_init=True,
                      need_accuracies=True)
# Out:
# Epoch 2... (Train/Test) Loss: 0.050/0.068
# Epoch 2... (Train/Test) Accuracies: 0.978/0.978
# ([0.21523715684345282, 0.0783488128040391, 0.050034719571939855],
#  [0.10084092789152756, 0.07577631601332864, 0.06752821462983384])

# %%
network = nn.Sequential(nn.Linear(784, 200),
                        LayerNormalization(),
                        nn.ReLU(),
                        nn.Linear(200, 200),
                        LayerNormalization(),
                        nn.ReLU(),
                        nn.Linear(200, 10),
                        nn.LogSoftmax())
train_utils.train(network, train_loader_mnist, test_loader_mnist, 20, learning_rate=0.001, ravel_init=True,
                      need_accuracies=True)
# Out:
# Epoch 12... (Train/Test) Loss: 0.014/0.074
# Epoch 12... (Train/Test) Accuracies: 0.978/0.978
# ([0.22785060172046678,
#   0.09353874774296274,
#   0.06305022253347103,
#   0.05329200735728719,
#   0.03949698683634988,
#   0.03169216386038564,
#   0.027981602128094703,
#   0.026813158822525888,
#   0.022581574055296715,
#   0.018873848046100677,
#   0.015244545592521348,
#   0.016395909276091927,
#   0.014467078524811475],
#  [0.1140968390752243,
#   0.09414792709241185,
#   0.07422486911940424,
#   0.08030172527025017,
#   0.0616330818060927,
#   0.06766187594879325,
#   0.08121548104984096,
#   0.05826065888262908,
#   0.06098532643687876,
#   0.060914653141193,
#   0.09284179852214418,
#   0.07762154809470419,
#   0.07382980675754856])

# %% [markdown]
# *Выводы:*
#
# ...

# %% [markdown]
# Спасибо за выполнение заданий!
#
# **Обратите внимание:**
# Ранее было отправлено домашнее задание (введение в pytorch, инициализация нейронных сетей) - оно тоже является обязательным!
